# %% [markdown]
# ### QUESTION 1

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

def convertToBST(root):
    values = []

    def inorderTraversal(node):
        nonlocal values

        if node is None:
            return

        inorderTraversal(node.left)
        values.append(node.val)
        inorderTraversal(node.right)

    def buildBST(node, index):
        if node is None:
            return

        buildBST(node.left, index)
        node.val = values[index[0]]
        index[0] += 1
        buildBST(node.right, index)

    inorderTraversal(root)
    values.sort()
    index = [0]
    buildBST(root, index)

    return root

def visualizeBST(root):
    def printBST(node, level=0):
        if node is None:
            return

        printBST(node.right, level + 1)
        print('    ' * level + str(node.val))
        printBST(node.left, level + 1)

    printBST(root)

# Example usage:
root = TreeNode(10)
root.left = TreeNode(2)
root.right = TreeNode(7)
root.left.left = TreeNode(8)
root.left.right = TreeNode(4)

converted_root = convertToBST(root)
visualizeBST(converted_root)
# Out:
#     10
# 8
#         7
#     4
#         2

# %% [markdown]
# ### QUESTION 2

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

def findDistance(root, node1, node2):
    def findLCA(root, node1, node2):
        if root is None:
            return None

        if root.val > node1.val and root.val > node2.val:
            return findLCA(root.left, node1, node2)

        if root.val < node1.val and root.val < node2.val:
            return findLCA(root.right, node1, node2)

        return root

    def findLevel(root, node, level):
        if root is None:
            return None

        if root.val == node.val:
            return level

        if root.val > node.val:
            return findLevel(root.left, node, level + 1)

        return findLevel(root.right, node, level + 1)

    def findDistanceUtil(root, node1, node2):
        lca = findLCA(root, node1, node2)

        d1 = findLevel(lca, node1, 0)
        d2 = findLevel(lca, node2, 0)

        return d1 + d2

    return findDistanceUtil(root, node1, node2)

def visualizeBST(root):
    def printBST(node, level=0):
        if node is None:
            return

        printBST(node.right, level + 1)
        print('    ' * level + str(node.val))
        printBST(node.left, level + 1)

    printBST(root)

# Example usage:
root = TreeNode(8)
root.left = TreeNode(3)
root.right = TreeNode(10)
root.left.left = TreeNode(1)
root.left.right = TreeNode(6)
root.left.right.left = TreeNode(4)
root.left.right.right = TreeNode(7)
root.right.right = TreeNode(14)
root.right.right.left = TreeNode(13)

node1 = TreeNode(6)
node2 = TreeNode(14)
print("The distance between the two keys:", findDistance(root, node1, node2))
visualizeBST(root)
# Out:
# The distance between the two keys: 4
#         14
#             13
#     10
# 8
#             7
#         6
#             4
#     3
#         1

# %% [markdown]
# ### QUESTION 3

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

class DoublyLinkedListNode:
    def __init__(self, value):
        self.val = value
        self.prev = None
        self.next = None

def convertToDoublyLinkedList(root):
    if root is None:
        return None

    def convert(root):
        nonlocal head, prev

        if root is None:
            return

        convert(root.left)

        node = DoublyLinkedListNode(root.val)

        if prev is None:
            head = node
        else:
            prev.next = node
            node.prev = prev

        prev = node

        convert(root.right)

    head = None
    prev = None
    convert(root)

    return head

def visualizeDoublyLinkedList(head):
    current = head
    while current:
        print(current.val, end=" ")
        current = current.next
    print()

# Example usage:
root = TreeNode(10)
root.left = TreeNode(5)
root.right = TreeNode(20)
root.right.left = TreeNode(30)
root.right.right = TreeNode(35)

doubly_linked_list_head = convertToDoublyLinkedList(root)
visualizeDoublyLinkedList(doubly_linked_list_head)
# Out:
# 5 10 30 20 35

# %% [markdown]
# ### QUESTION 4

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None
        self.next = None

def connectNodesAtSameLevel(root):
    if root is None:
        return None

    queue = [root]

    while queue:
        size = len(queue)

        for i in range(size):
            node = queue.pop(0)

            if i < size - 1:
                node.next = queue[0]

            if node.left:
                queue.append(node.left)

            if node.right:
                queue.append(node.right)

    return root

def visualizeConnections(root):
    queue = [root]

    while queue:
        node = queue.pop(0)
        print(node.val, end=" → ")
        if node.next:
            print(node.next.val, end=" ")
        else:
            print("-1")
        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)

# Example usage:
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

connected_root = connectNodesAtSameLevel(root)
visualizeConnections(connected_root)
# Out:
# 1 → -1
# 2 → 3 3 → -1
# 4 → 5 5 → 6 6 → 7 7 → -1
